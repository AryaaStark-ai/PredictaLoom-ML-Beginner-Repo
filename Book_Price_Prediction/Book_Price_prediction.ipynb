# %% [markdown]
# #**Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**Import Data**

# %%
df = pd.read_excel('/content/drive/MyDrive/ML_Predictions/DataSets/Data.Book_prediction/Participants_Data/Data_Train.xlsx')

# %%
df
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition             Reviews              Ratings  \
# ...

# %%
dt = pd.read_excel('/content/drive/MyDrive/ML_Predictions/DataSets/Data.Book_prediction/Participants_Data/Data_Test.xlsx')

# %%
dt
# Out:
#                                                   Title  \
# 0            The Complete Sherlock Holmes: 2 Boxes sets
# 1     Learn Docker - Fundamentals of Docker 18.x: Ev...
# 2                                              Big Girl
# 3     Think Python: How to Think Like a Computer Sci...
# 4     Oxford Word Skills: Advanced - Idioms & Phrasa...
# ...                                                 ...
# 1555  100 Things Every Designer Needs to Know About ...
# 1556  Modern Letter Writing Course: Personal, Busine...
# 1557                      The Kite Runner Graphic Novel
# 1558    Panzer Leader (Penguin World War II Collection)
# 1559                      Complete Spanish Step-by-Step
#
#                       Author                             Edition  \
# 0     Sir Arthur Conan Doyle  Mass Market Paperback,– 1 Oct 1986
# 1        Gabriel N. Schenker     Paperback,– Import, 26 Apr 2018
# 2             Danielle Steel             Paperback,– 17 Mar 2011
# ...

# %% [markdown]
# #**Data Cleaning**

# %%
df.isnull().count()
# Out:
# Title           6237
# Author          6237
# Edition         6237
# Reviews         6237
# Ratings         6237
# Synopsis        6237
# Genre           6237
# BookCategory    6237
# Price           6237
# dtype: int64

# %%
dt.isnull().count()
# Out:
# Title           1560
# Author          1560
# Edition         1560
# Reviews         1560
# Ratings         1560
# Synopsis        1560
# Genre           1560
# BookCategory    1560
# dtype: int64

# %%
df
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition             Reviews              Ratings  \
# ...

# %%
#Handling Edition column
df['Edition'] = df['Edition'].str.extract('(\d{4})', expand=False)

# %%
#Handling Reviews column
df['Reviews'] = df['Reviews'].str.extract('(\d\.\d)', expand=False).astype(float)

# %%
#Handling Ratings column
df['Ratings'] = df['Ratings'].str.extract('(\d+)', expand=False).astype(int)

# %%
# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)
# Out:
# Cleaned DataFrame:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#      Edition  Reviews  Ratings  \
# 0       2016      4.0        8
# ...

# %% [markdown]
# #Feature Extraction

# %%
features = df[['Author', 'Edition', 'Reviews', 'Ratings', 'Synopsis', 'Genre', 'BookCategory']]

# %% [markdown]
# #Text DataProcessing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD


vectorizer = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(n_components=10, random_state=42)

synopsis_features = svd.fit_transform(vectorizer.fit_transform(df['Synopsis']))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD


vectorizer = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(n_components=10, random_state=42)

Genre_features = svd.fit_transform(vectorizer.fit_transform(df['Genre']))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD


vectorizer = TfidfVectorizer(stop_words='english')
svd = TruncatedSVD(n_components=10, random_state=42)

BookCategory_features = svd.fit_transform(vectorizer.fit_transform(df['BookCategory']))

# %%
synopsis_features
# Out:
# array([[ 0.0971851 , -0.06131075,  0.01140618, ...,  0.05765988,
#         -0.00850728,  0.035091  ],
#        [ 0.10806511,  0.00721456, -0.0014995 , ...,  0.00980243,
#         -0.01673198, -0.0445017 ],
#        [ 0.19175686, -0.00337795,  0.0014093 , ...,  0.20485932,
#          0.23489696, -0.04871249],
#        ...,
#        [ 0.09850156, -0.0638261 ,  0.0245719 , ..., -0.04241675,
#          0.00350332, -0.00817162],
#        [ 0.07281035, -0.04696412,  0.00848628, ..., -0.01141376,
#          0.0137119 , -0.00134478],
#        [ 0.10769486, -0.09666026,  0.01361641, ...,  0.02679545,
#          0.02766546,  0.05121524]])

# %% [markdown]
# #**Data Exploration and Analysis**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Price'], kde=True)
plt.show()

# Check correlations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-18-16ea13a4b641>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the 'Synopsis' column
text = ' '.join(df['Synopsis'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the WordCloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ' '.join(df['Genre'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the WordCloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ' '.join(df['BookCategory'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the WordCloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #**Feature Engineering**

# %%
df = pd.concat([df, pd.DataFrame(synopsis_features, columns=[f'Synopsis_{i}' for i in range(1, 11)])], axis=1)
df['IsFiction'] = df['Genre'].apply(lambda x: 1 if 'Fiction' in x else 0)
df['IsNonFiction'] = df['Genre'].apply(lambda x: 1 if 'Non-Fiction' in x else 0)
df['IsBiography'] = df['BookCategory'].apply(lambda x: 1 if 'Biographies' in x else 0)
df['IsHumour'] = df['BookCategory'].apply(lambda x: 1 if 'Humour' in x else 0)

# %%
df
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#      Edition  Reviews  Ratings  \
# 0       2016      4.0        8
# ...

# %% [markdown]
# #**Data Split**

# %% [markdown]
# #Train-Test Split

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df.drop('Price', axis=1), df['Price'], test_size=0.2, random_state=42)

# %% [markdown]
# #**Model Selection**

# %%
features = df[['Reviews', 'Ratings', 'IsFiction', 'IsNonFiction', 'IsBiography', 'IsHumour']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(features, df['Price'], test_size=0.2, random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 412680.9784086579

# %%
X_test_dt = dt

# %% [markdown]
# #**HyperParameter Tunning**

# %%
from sklearn.model_selection import GridSearchCV

# Example with hyperparameter tuning for a RandomForestRegressor
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# %% [markdown]
# #**Deployment**

# %%
import joblib

# Save the trained model
joblib.dump(best_model, 'book_price_prediction_model.joblib')
# Out:
# ['book_price_prediction_model.joblib']

# %%
# Load the trained model
loaded_model = joblib.load('book_price_prediction_model.joblib')

# Assuming 'new_data' is a DataFrame with the same features as in training
predictions = loaded_model.predict(X_test)

# %%
feature_importance = best_model.feature_importances_
print('Feature Importance:', feature_importance)
# Out:
# Feature Importance: [0.31787192 0.5908186  0.025057   0.         0.03121602 0.03503646]

# %%
from sklearn.model_selection import cross_val_score

# Assuming 'best_model' is your trained and optimized model
cv_scores = cross_val_score(best_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
cv_mse = -cv_scores.mean()
print(f'Cross-Validation Mean Squared Error: {cv_mse}')
# Out:
# Cross-Validation Mean Squared Error: 472172.34749655816

# %%
from sklearn.ensemble import VotingRegressor

# Assuming 'best_model' is your trained and optimized model
ensemble_model = VotingRegressor(estimators=[('best_model', best_model)])

# Train the ensemble model
ensemble_model.fit(X_train, y_train)

# Make predictions
ensemble_predictions = ensemble_model.predict(X_test)
ensemble_mse = mean_squared_error(y_test, ensemble_predictions)
print(f'Ensemble Model Mean Squared Error: {ensemble_mse}')
# Out:
# Ensemble Model Mean Squared Error: 427957.48114054627
